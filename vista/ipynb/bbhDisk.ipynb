# %% [markdown]
# # BBH Disks

# %%
using Plots
include("../../Utils/misc.jl")
# Out:
# Main.Misc

# %% [markdown]
# ## Uniform Grid

# %% [markdown]
# ### Scaling

# %%
let patt_dirs = [
        (r"Cow_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk"; option="TotalComputeTime") 
    #
    plt = plot(ylabel="M/day")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [333.24855468867577, 417.68605518426244, 372.97696758050336, 479.11373232688544]
# [411.7818207722823, 499.76385113127543, 372.16332180620066, 521.3459070920484]
# [456.49359687284976, 541.872080639888, 472.29160513803606, 524.1755132504932]
# [423.3475410184315, 522.8350226255762, 484.87087025573845, 527.608884101537]

# %%
let patt_dirs = [
        (r"Cow_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk", option="ZcsPerSecond") 
    #
    plt = plot(ylabel="Zcs/sec")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [5.833444375e7, 7.32201875e7, 7.124995625e7, 8.412845625e7]
# [7.22174625e7, 8.7742765625e7, 7.2946409375e7, 9.1567478125e7]
# [8.008584375e7, 9.513781875e7, 8.66458625e7, 9.210439375e7]
# [7.4303146875e7, 9.1778671875e7, 8.7005746875e7, 9.28011875e7]

# %% [markdown]
# ### Speed

# %%
let dirs = [
        ("Cow_L12_G256-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Cow_L12_G256-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Cow_L12_G256-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Cow_L12_G256-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Cow_L12_G128-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Cow_L12_G128-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Cow_L12_G128-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Cow_L12_G128-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Cow_L12_G64-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Cow_L12_G64-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Cow_L12_G64-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Cow_L12_G64-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Cow_L12_G32-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Cow_L12_G32-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Cow_L12_G32-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Cow_L12_G32-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end
