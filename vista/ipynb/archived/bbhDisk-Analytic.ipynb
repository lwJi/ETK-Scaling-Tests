# %% [markdown]
# # BBH Disks with Analytic Spacetime

# %%
using Plots
include("../../Utils/misc.jl")
# Out:
# Main.Misc

# %% [markdown]
# ## Uniform Grid

# %% [markdown]
# ### Scaling

# %%
let patt_dirs = [
        (r"Ana_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Ana_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Ana_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Ana_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk"; option="TotalComputeTime") 
    #
    plt = plot(ylabel="M/day")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [340.2351890988158, 417.90256649094454, 477.9408867636413, 481.0723049950134]
# [416.9517331293707, 502.49337573248766, 527.9715811253882, 513.4811815588479]
# [449.9811298235881, 540.759575320896, 541.3495319945981, 520.9256518976879]
# [432.1849640114366, 520.2683366306452, 537.7516430336492, 499.3409534632128]

# %%
let patt_dirs = [
        (r"Ana_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Ana_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Ana_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Ana_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk", option="ZcsPerSecond") 
    #
    plt = plot(ylabel="Zcs/sec")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [5.9550884375e7, 7.32723375e7, 8.3872503125e7, 8.4422953125e7]
# [7.3125740625e7, 8.8201184375e7, 9.2710271875e7, 9.018603125e7]
# [7.8937075e7, 9.4940221875e7, 9.5132146875e7, 9.15528625e7]
# [7.587671875e7, 9.135705625e7, 9.448525625e7, 8.82790375e7]

# %% [markdown]
# ### Speed

# %%
let dirs = [
        ("Ana_L12_G256-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G256-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G256-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G256-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G128-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G128-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G128-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G128-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G64-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G64-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G64-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G64-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G32-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G32-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G32-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G32-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end
