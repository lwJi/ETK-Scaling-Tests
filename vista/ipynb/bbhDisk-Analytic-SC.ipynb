# %% [markdown]
# # BBH Disks with Analytic Spacetime (with Subcycling)

# %%
using Plots
include("../../Utils/misc.jl")
# Out:
# Main.Misc

# %% [markdown]
# ## Uniform Grid

# %% [markdown]
# ### Scaling

# %%
let patt_dirs = [
        (r"Ana_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Ana_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Ana_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Ana_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk-SC"; option="TotalComputeTime") 
    #
    plt = plot(ylabel="M/day")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [683.012173447555, 1089.2148985858946, 1432.9237602384712, 1574.0076981576026]
# [1255.1747842134105, 1657.1441921352769, 1934.6687555849983, 1817.2936003908158]
# [1429.2076076874635, 1903.5896652138433, 2001.7075498095153, 1917.474816247724]
# [1348.131316043536, 1735.260958784546, 1887.0187538551995, 1993.6375095394483]

# %%
let patt_dirs = [
        (r"Ana_L12_G32-N\d+-MPI\d+_r0000", "G32"),
        (r"Ana_L12_G64-N\d+-MPI\d+_r0000", "G64"),
        (r"Ana_L12_G128-N\d+-MPI\d+_r0000", "G128"),
        (r"Ana_L12_G256-N\d+-MPI\d+_r0000", "G256"),
    ]
    (dats, labs) = Misc.load_avgs(patt_dirs, "../data/bbhDisk-SC", option="ZcsPerSecond") 
    #
    plt = plot(ylabel="Zcs/sec")
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[2], label=labs[i],
              marker=:circle, xscale=:log10, yscale=:log10)
        println(dat[2])
    end
    display(plt)
end
# Out:
# [1.39576996875e8, 2.2535399375e8, 2.974880625e8, 3.3369818125e8]
# [2.56905121875e8, 3.428695875e8, 4.11102453125e8, 3.83763640625e8]
# [2.94598034375e8, 3.99446346875e8, 4.2374855625e8, 4.1252253125e8]
# [2.924623e8, 3.5711940625e8, 3.99218359375e8, 4.318395e8]

# %% [markdown]
# ### Speed

# %%
let dirs = [
        ("Ana_L12_G256-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G256-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G256-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G256-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk-SC", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G128-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G128-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G128-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G128-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk-SC", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G64-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G64-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G64-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G64-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk-SC", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end

# %%
let dirs = [
        ("Ana_L12_G32-N8-MPI8_r0000/stdout.txt", "N8"),
        ("Ana_L12_G32-N16-MPI16_r0000/stdout.txt", "N16"),
        ("Ana_L12_G32-N32-MPI32_r0000/stdout.txt", "N32"),
        ("Ana_L12_G32-N64-MPI64_r0000/stdout.txt", "N64"),
    ]
    (dats, labs) = Misc.load_data(dirs, "../data/bbhDisk-SC", "TotalComputeTime")
    #
    plt = plot()
    for (i, dat) in enumerate(dats)
        plot!(plt, dat[1], dat[3], label=labs[i])
    end
    display(plt)
end
