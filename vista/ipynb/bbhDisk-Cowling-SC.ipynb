# %% [markdown]
# # BBH Disks with Subcycling (Cowling with 12 levels of refinement)

# %%
using Plots
include("../../Utils/misc.jl")
# Out:
# Main.Misc

# %% [markdown]
# ## Scaling

# %% [markdown]
# ### bbhDisk-n256-v1

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v1", :cross),
    ]
    
    # Plot M/day
    plt1 = plot(ylabel="M/day", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1800, 2000, 2200, 2400, 2600]
    yticks!(plt1, ys, [string(n) for n in ys])
    println("M/day")
    Misc.plot_scaling(plt1, patt_dirss; option="TotalComputeTime", is_print_value=true, is_plot_ideal=false)
    
    # Plot Zcs/sec
    plt2 = plot(ylabel="Zcs/sec", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt2, xs, [string(n) for n in xs])
    ys = [4e8, 4.5e8, 5e8, 5.5e8, 6e8]
    yticks!(plt2, ys, [string(n) for n in ys])
    println("Zcs/sec")
    Misc.plot_scaling(plt2, patt_dirss; option="ZcsPerSecond", is_print_value=true)

    # Sum
    plt = plot(plt1, plt2, layout=(2,1))
    display(plt)
end
# Out:
# M/day
#        G64: [ 1.71e+03, 2.62e+03, 2.29e+03, 2.34e+03,]
#       G128: [ 1.95e+03, 2.46e+03, 2.52e+03, 2.24e+03,]
#       G256: [ 1.99e+03, 2.56e+03, 2.39e+03, 2.35e+03,]
#    Gtheory: [ 1.99e+03, 2.54e+03, 2.38e+03, 2.24e+03,]
# Zcs/sec
#        G64: [ 4.22e+08, 6.25e+08, 4.70e+08, 4.43e+08,]
#       G128: [ 5.09e+08, 5.50e+08, 5.12e+08, 4.13e+08,]
#       G256: [ 5.33e+08, 5.86e+08, 4.74e+08, 4.49e+08,]
#    Gtheory: [ 4.81e+08, 5.75e+08, 4.97e+08, 4.02e+08,]

# %% [markdown]
# ### bbhDisk-n256-v2

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v2", :xcross),
    ]
    
    # Plot M/day
    plt1 = plot(ylabel="M/day", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1200, 1600, 2000, 2400]
    yticks!(plt1, ys, [string(n) for n in ys])
    println("M/day")
    Misc.plot_scaling(plt1, patt_dirss; option="TotalComputeTime", is_print_value=true)
    
    # Plot Zcs/sec
    plt2 = plot(ylabel="Zcs/sec", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt2, xs, [string(n) for n in xs])
    ys = [3e8, 4e8, 5e8, 6e8]
    yticks!(plt2, ys, [string(n) for n in ys])
    println("Zcs/sec")
    Misc.plot_scaling(plt2, patt_dirss; option="ZcsPerSecond", is_print_value=true)

    # Sum
    plt = plot(plt1, plt2, layout=(2,1))
    display(plt)
end
# Out:
# M/day
#        G64: [ 1.15e+03, 1.99e+03, 2.16e+03, 2.37e+03,]
#       G128: [ 1.39e+03, 2.01e+03, 2.49e+03, 2.27e+03,]
#       G256: [ 1.57e+03, 2.13e+03, 2.29e+03, 2.37e+03,]
#    Gtheory: [ 1.32e+03, 2.11e+03, 2.60e+03, 2.50e+03,]
# Zcs/sec
#        G64: [ 2.54e+08, 4.25e+08, 4.54e+08, 4.81e+08,]
#       G128: [ 3.11e+08, 4.41e+08, 5.11e+08, 4.51e+08,]
#       G256: [ 3.72e+08, 4.70e+08, 4.78e+08, 4.75e+08,]
#    Gtheory: [ 2.87e+08, 4.42e+08, 5.95e+08, 4.98e+08,]

# %% [markdown]
# ### bbhDisk-n360-v1

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v1", :star4),
    ]
    
    # Plot M/day
    plt1 = plot(ylabel="M/day", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1200, 1500, 1800, 2100, 2400]
    yticks!(plt1, ys, [string(n) for n in ys])
    println("M/day")
    Misc.plot_scaling(plt1, patt_dirss; option="TotalComputeTime", is_print_value=true)
    
    # Plot Zcs/sec
    plt2 = plot(ylabel="Zcs/sec", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt2, xs, [string(n) for n in xs])
    ys = [5e8, 6e8, 7e8, 8e8, 9e8]
    yticks!(plt2, ys, [string(n) for n in ys])
    println("Zcs/sec")
    Misc.plot_scaling(plt2, patt_dirss; option="ZcsPerSecond", is_print_value=true)

    # Sum
    plt = plot(plt1, plt2, layout=(2,1))
    display(plt)
end
# Out:
# M/day
#        G64: [ 1.79e+03, 2.17e+03, 2.29e+03,]
#       G128: [ 1.19e+03, 1.95e+03, 2.23e+03, 2.35e+03,]
#       G256: [ 1.20e+03, 1.96e+03, 2.18e+03, 2.44e+03,]
#    Gtheory: [ 1.20e+03, 1.94e+03, 2.16e+03, 2.55e+03,]
# Zcs/sec
#        G64: [ 6.92e+08, 7.84e+08, 8.05e+08,]
#       G128: [ 5.08e+08, 8.05e+08, 8.06e+08, 8.12e+08,]
#       G256: [ 5.51e+08, 8.25e+08, 8.87e+08, 8.44e+08,]
#    Gtheory: [ 4.77e+08, 7.19e+08, 8.39e+08, 8.96e+08,]

# %% [markdown]
# ### bbhDisk-n360-v2

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G160-N\d+-MPI\d+_r0000", "G160"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_G320-N\d+-MPI\d+_r0000", "G320"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v2", :star4),
    ]
    # Plot M/day
    plt1 = plot(ylabel="M/day", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1100, 1300, 1500, 1700, 1900, 2100]
    yticks!(plt1, ys, [string(n) for n in ys])
    println("M/day")
    Misc.plot_scaling(plt1, patt_dirss; option="TotalComputeTime", is_print_value=true)
    
    # Plot Zcs/sec
    plt2 = plot(ylabel="Zcs/sec", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt2, xs, [string(n) for n in xs])
    ys = [4e8, 5e8, 6e8, 7e8, 8e8]
    yticks!(plt2, ys, [string(n) for n in ys])
    println("Zcs/sec")
    Misc.plot_scaling(plt2, patt_dirss; option="ZcsPerSecond", is_print_value=true)

    # Sum
    plt = plot(plt1, plt2, layout=(2,1))
    display(plt)
end
# Out:
# M/day
#        G64: [ 1.06e+03, 1.53e+03, 1.57e+03,]
#       G128: [ 1.22e+03, 1.73e+03, 2.01e+03,]
#       G160: [ 1.19e+03, 1.80e+03, 2.09e+03,]
#       G256: [ 1.20e+03, 1.66e+03, 2.04e+03,]
#       G320: [ 1.30e+03, 1.83e+03, 2.09e+03,]
#    Gtheory: [ 1.18e+03, 1.65e+03,]
# Zcs/sec
#        G64: [ 3.96e+08, 6.06e+08, 6.25e+08,]
#       G128: [ 4.76e+08, 6.55e+08, 7.79e+08,]
#       G160: [ 4.40e+08, 6.85e+08, 8.08e+08,]
#       G256: [ 4.97e+08, 6.31e+08, 7.88e+08,]
#       G320: [ 4.96e+08, 7.00e+08, 8.08e+08,]
#    Gtheory: [ 4.39e+08, 6.56e+08,]

# %% [markdown]
# ### In Sum

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v1", :cross),
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v2", :xcross),
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v1", :star4),
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G160-N\d+-MPI\d+_r0000", "G160"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_G320-N\d+-MPI\d+_r0000", "G320"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v2", :utriangle),
    ]
    
    # Plot M/day
    plt1 = plot(ylabel="M/day", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1100, 1300, 1500, 1700, 1900, 2100, 2300, 2500]
    yticks!(plt1, ys, [string(n) for n in ys])
    println("M/day")
    Misc.plot_scaling(plt1, patt_dirss; option="TotalComputeTime", is_print_value=false)
    
    # Plot Zcs/sec
    plt2 = plot(ylabel="Zcs/sec", xscale=:log10, yscale=:log10)
    xs = [4, 8, 16, 32]
    xticks!(plt2, xs, [string(n) for n in xs])
    ys = [3e8, 4e8, 5e8, 6e8, 7e8, 8e8, 9e8]
    yticks!(plt2, ys, [string(n) for n in ys])
    println("Zcs/sec")
    Misc.plot_scaling(plt2, patt_dirss; option="ZcsPerSecond", is_print_value=false)

    # Sum
    plt = plot(plt1, plt2, layout=(2,1), size = (600, 675))
    display(plt)
end
# Out:
# M/day
# Zcs/sec

# %% [markdown]
# ## Speed

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v1", :cross),
    ]
    
    #
    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = Misc.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[3], label=labs[i])
            end
            push!(plts, plt)
        end
    end
    
    plt = plot(plts..., layout=(1,4), size=(1200, 300))
    display(plt)
end

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n256-v2", :xcross),
    ]
    
    #
    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = Misc.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[3], label=labs[i])
            end
            push!(plts, plt)
        end
    end
    
    plt = plot(plts..., layout=(1,4), size=(1200, 300))
    display(plt)
end

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v1", :star4),
    ]
    
    #
    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = Misc.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[3], label=labs[i])
            end
            push!(plts, plt)
        end
    end
    
    plt = plot(plts..., layout=(1,4), size=(1200, 300))
    display(plt)
end

# %%
let patt_dirss = [
        ([
            (r"Cow_L12_G64-N\d+-MPI\d+_r0000", "G64"),
            (r"Cow_L12_G128-N\d+-MPI\d+_r0000", "G128"),
            (r"Cow_L12_G160-N\d+-MPI\d+_r0000", "G160"),
            (r"Cow_L12_G256-N\d+-MPI\d+_r0000", "G256"),
            (r"Cow_L12_G320-N\d+-MPI\d+_r0000", "G320"),
            (r"Cow_L12_Gtheory-N\d+-MPI\d+_r0000", "Gtheory"),
        ], "../data/bbhDisk-SC/bbhDisk-n320-v2", :utriangle),
    ]
    
    #
    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = Misc.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[3], label=labs[i])
            end
            push!(plts, plt)
        end
    end
    
    plt = plot(plts..., layout=(2,4), size=(1200, 600))
    display(plt)
end
