# %% [markdown]
# # BBH Disk Meshes

# %%
using GLMakie
using GeometryBasics
using SplitApplyCombine

# %%
function get_rectangles(pos, rads)
    recs = Vector{Rect3}()
    for rad in rads
        org = pos .- rad
        push!(recs, Rect3(Point3f(org), Vec3f(rad * 2)))
    end
    return recs
end
# Out:
# get_rectangles (generic function with 1 method)

# %% [markdown]
# ## Discussion

# %% [markdown]
# * From level 1 to 10: $320^3$
# * From level 11 to 12: $160^3 \times 2$

# %%
(320/10*5)
# Out:
# 160.0

# %% [markdown]
# ### Best max_grid_sizes (Gtheory)

# %%
[[cbrt((320^3)/n), cbrt((160^3)/(n/2))] for n in [4, 8, 16, 32, 64]]
# Out:
# 5-element Vector{Vector{Float64}}:
#  [201.58736798317972, 126.99208415745596]
#  [160.0, 100.79368399158986]
#  [126.99208415745596, 80.0]
#  [100.79368399158986, 63.49604207872798]
#  [80.0, 50.39684199579493]

# %% [markdown]
# ## Paramters

# %%
# Set rectangles
pos_1 = [-6.508727e+00, -7.591869e+00, 0.0]
pos_2 = [ 6.508727e+00,  7.591869e+00, 0.0]
pos_3 = [0.0, 0.0, 0.0]

rads_1 = [
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
]
rads_2 = [
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
    [-1., 10., 10., 10., 10., 10., 10., 10., 10., 10., 5., 2.5],
]
rads_3 = [
    [-1., 5120., 2560., 1280., 640., 320., 160., 80., 40., 20.],
    [-1., 5120., 2560., 1280., 640., 320., 160., 80., 40., 20.],
    [-1., 5120., 2560., 1280., 640., 320., 160., 80., 40., 20.],
]

# Rectangles
recs_1 = get_rectangles(pos_1, invert(rads_1))
recs_2 = get_rectangles(pos_2, invert(rads_2))
recs_3 = get_rectangles(pos_3, invert(rads_3))

println(length(recs_1), ", ", length(recs_2), ", ", length(recs_3))
# Out:
# 12, 12, 10

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Down to Level 9

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9],
    ]
    # Plot
    #with_theme(theme_dark()) do
    fig = Figure(size = (1200,800))
    axs = [
        Axis3(fig[1, 1]; aspect = :data, azimuth=1.275pi, elevation=pi/8),
        Axis3(fig[1, 2]; aspect = :data, azimuth=1.2pi, elevation=pi/8),
        Axis3(fig[2, 1]; aspect = :data, azimuth=1.125pi, elevation=pi/8),
        Axis3(fig[2, 2]; aspect = :data, azimuth=1.05pi, elevation=pi/8),
    ]
    #meshscatter!(fig[1, 1], r12_1)
    #wireframe!(fig[1, 1], r12_1)
    for ax in axs
        for rec in recs
            mesh!(ax, rec, transparency = true, alpha = 0.5)
        end
    end
    fig
    #end
end

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9],
    ]
    # Plot
    #with_theme(theme_dark()) do
    fig = Figure(size = (1200,800))
    axs = [
        Axis3(fig[1, 1]; aspect = :data, azimuth=0pi, elevation=0pi),
        Axis3(fig[1, 2]; aspect = :data, azimuth=0pi, elevation=pi/2),
    ]
    #meshscatter!(fig[1, 1], r12_1)
    #wireframe!(fig[1, 1], r12_1)
    for ax in axs
        for rec in recs
            mesh!(ax, rec, transparency = true, alpha = 0.5)
        end
    end
    fig
    #end
end

# %% [markdown]
# ### Down to Level 7

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect =:data)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end

# %% [markdown]
# ### Down to Level 4

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7], recs_3[6], recs_3[5], recs_3[4],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect = :data, azimuth=1.275pi, elevation=pi/8)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end
