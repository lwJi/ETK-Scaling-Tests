# %%
using GLMakie
using GeometryBasics
using SplitApplyCombine

# %%
function get_rectangles(pos, rads)
    recs = Vector{Rect3}()
    for rad in rads
        org = pos .- rad
        push!(recs, Rect3(Point3f(org), Vec3f(rad * 2)))
    end
    return recs
end
# Out:
# get_rectangles (generic function with 1 method)

# %% [markdown]
# ## Paramters

# %%
# Set rectangles
pos_1 = [-6.508727e+00, -7.591869e+00, 0.0]
pos_2 = [ 6.508727e+00,  7.591869e+00, 0.0]
pos_3 = [0.0, 0.0, 0.0]

rads_1 = [
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
]
rads_2 = [
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
    [-1., 6., 6., 6., 6., 6., 6., 6., 6., 6., 3., 1.5],
]
rads_3 = [
    [-1., 4096., 2048., 1024., 512., 256., 128., 64., 32., 20.],
    [-1., 4096., 2048., 1024., 512., 256., 128., 64., 32., 20.],
    [-1.,  144.,  144.,  144., 144., 120.,  72., 48., 24., 20.],
]

# Rectangles
recs_1 = get_rectangles(pos_1, invert(rads_1))
recs_2 = get_rectangles(pos_2, invert(rads_2))
recs_3 = get_rectangles(pos_3, invert(rads_3))

println(length(recs_1), ", ", length(recs_2), ", ", length(recs_3))
# Out:
# 12, 12, 10

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Down to Level 9

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9],
    ]
    # Plot
    #with_theme(theme_dark()) do
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1]; aspect = :data) #limits = ((-20, 20), (-20, 20), (-10, 10)))
    #meshscatter!(fig[1, 1], r12_1)
    #wireframe!(fig[1, 1], r12_1)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
    #end
end

# %% [markdown]
# ### Down to Level 7

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect =:data)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end

# %% [markdown]
# ### Down to Level 4

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7], recs_3[6], recs_3[5], recs_3[4],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect = :data, azimuth=1.275pi, elevation=pi/8)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7], recs_3[6], recs_3[5], recs_3[4],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect = :data, azimuth = 0, elevation = 0)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end

# %%
let recs = [
        recs_1[11], recs_1[12],
        recs_2[11], recs_2[12],
        recs_3[10], recs_3[9], recs_3[8], recs_3[7], recs_3[6], recs_3[5], recs_3[4],
    ]
    # Plot
    fig = Figure(size = (1200,800))
    ax = Axis3(fig[1, 1], aspect = :data, azimuth = 0, elevation = pi/2)
    for rec in recs
        mesh!(fig[1, 1], rec, transparency = true, alpha = 0.5)
    end
    fig
end
