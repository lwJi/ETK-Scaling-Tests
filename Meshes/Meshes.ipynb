# %%
using GLMakie, Random, Colors, LinearAlgebra
using Makie
using GeometryBasics
GLMakie.closeall() # close any open screen

r12_1 = Rect3(Point3f(-6.508727e+00-4, -7.591869e+00-4, 0.0-4), Vec3f(1))
r12_2 = Rect3(Point3f(6.508727e+00-4, 7.591869e+00-4, 0.0-4), Vec3f(1))

markers = [r12_1, r12_2]

with_theme(theme_dark()) do
    fig = Figure(size = (1200,800))
    axs = [Axis3(fig[i, j]; aspect = :data, perspectiveness = 0.5) for j in 1:1, i in 1:1]
    [meshscatter!(axs[1], Point3f(0); marker = markers[i], markersize = 0.25) for i in 1:2]
    fig
end
