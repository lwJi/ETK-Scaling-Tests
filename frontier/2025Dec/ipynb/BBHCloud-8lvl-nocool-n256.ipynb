# %% [markdown]
# # BBHCloud (8 levels, no cooling, n256)

# %%
using Plots, Printf, Measures
using LaTeXStrings
include("../../../Utils/misc_stdout.jl")
# Out:
# Main.MiscStdout

# %% [markdown]
# ## Strong Scaling

# %%
let patt_dirss = [
        ([
            (r"BBHCloud_8lvl_nocool_N\d+_r0000", "BBHCloud-8lvl-nocool"),
        ], "../data/BBHCloud_8lvl_nocool/n256/strong/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [1, 2, 4, 8, 16]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1e8, 1e9, 1e10]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])

    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1], dat[2], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1], dat[2][1] .* dat[1], label="", linestyle=:dash, color=:lightgray)

            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Efficiency
            value_per_node = dat[2] ./ dat[1]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1], efficiency, label="", marker = mark)
        end
    end

    plt = plot(plt1, plt2, layout=(2,1))
    display(plt)
end
# Out:
# Zcs/sec
# AssertionError: Provided `parent_dir` is not a valid directory.
#
# Stacktrace:
#  [1] load_avgs(dir_patterns::Vector{Tuple{Regex, String}}, parent_dir::String; range::Function, option::String, fname::String)
#    @ Main.MiscStdout ~/docker-workspace/repos/ETK-Scaling-Tests/Utils/misc_stdout.jl:262
#  [2] top-level scope
#    @ In[2]:21

# %% [markdown]
# ## Weak Scaling

# %%
let patt_dirss = [
        ([
            (r"BBHCloud_8lvl_nocool_N\d+_r0000", "BBHCloud-8lvl-nocool"),
        ], "../data/BBHCloud_8lvl_nocool/n256/weak/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [1, 8, 64, 216, 512, 1000, 2197]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1e8, 1e9, 1e10]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xlabel=L"\mathrm{Frontier\,\,Nodes}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])

    plt3 = plot(ylabel=L"\mathrm{Zcs/sec/Node}", xscale=:log10)
    xticks!(plt3, xs, [string(n) for n in xs])

    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1], dat[2], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1], dat[2][1] .* dat[1], label="", linestyle=:dash, color=:lightgray)

            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Zcs/sec/Node
            plot!(plt3, dat[1], dat[2] ./ dat[1], label = "",  marker = mark)

            # Plot Efficiency
            value_per_node = dat[2] ./ dat[1]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1], efficiency, label="", marker = mark, ylims=(0, 1.1))
        end
    end

    #plt = plot(plt1, plt3, plt2, layout=(3,1), size=(600, 600))
    plt = plot(plt2, layout=(3,1), size=(600, 400))
    display(plt)
    #savefig(plt, "BBHCloud-8lvl-nocool-weak-scaling.pdf")
end
# Out:
# Zcs/sec
#   BBHCloud-8lvl-nocool: [ 1.08e+08, 7.98e+08, 5.98e+09, 1.91e+10, 4.11e+10, 7.21e+10, 1.07e+11]

# %% [markdown]
# ## Speed

# %%
let patt_dirss = [
        ([
            (r"BBHCloud_8lvl_nocool_N\d+_r0000", "BBHCloud-8lvl-nocool-strong"),
        ], "../data/BBHCloud_8lvl_nocool/n256/strong/", :cross),
        ([
            (r"BBHCloud_8lvl_nocool_N\d+_r0000", "BBHCloud-8lvl-nocool-weak"),
        ], "../data/BBHCloud_8lvl_nocool/n256/weak/", :circle),
    ]

    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = MiscStdout.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[4], label=labs[i], marker=mark)
            end
            push!(plts, plt)
        end
    end

    plt = plot(plts..., layout=(length(plts), 1), size=(600, 300 * length(plts)))
    display(plt)
end
# Out:
# AssertionError: Provided `parent_dir` is not a valid directory.
#
# Stacktrace:
#  [1] load_values(dir_patterns::Vector{Tuple{Regex, String}}, parent_dir::String; option::String, fname::String)
#    @ Main.MiscStdout ~/docker-workspace/repos/ETK-Scaling-Tests/Utils/misc_stdout.jl:210
#  [2] load_values
#    @ ~/docker-workspace/repos/ETK-Scaling-Tests/Utils/misc_stdout.jl:204 [inlined]
#  [3] top-level scope
#    @ ./In[7]:12
