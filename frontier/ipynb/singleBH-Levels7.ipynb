# %% [markdown]
# # Single BH

# %%
using Plots, Printf, Measures
using LaTeXStrings
include("../../Utils/misc-stdout.jl")
# Out:
# Main.MiscStdout

# %% [markdown]
# ## Level5

# %%
let patt_dirss = [
        ([
            (r"singleBH_Z4cowGPU_L5_N\d+_r0000", "singleBH-Z4cowGPU-5Levels"),
        ], "../data/singleBH-Scaling/Levels5/Block8/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [64, 128, 256, 512, 1024, 2048, 4096]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [4e9, 1.6e10, 6.4e10]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])
    
    plt3 = plot(ylabel=L"\mathrm{Zcs/sec/GPU}", xscale=:log10)
    xticks!(plt3, xs, [string(n) for n in xs])
    ys = [3.5e7, 4e7, 4.5e7]
    yticks!(plt3, ys, [string(n) for n in ys])

    range=2:8
    
    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1][range] * 8, dat[2][range], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1][range] * 8, dat[2][2] .* dat[1][range] / 8, label="", linestyle=:dash, color=:lightgray)
            
            plot!(plt3, dat[1][range] * 8, dat[2][range] ./ (dat[1][range] * 8), label = "",  marker = mark)
            
            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Efficiency
            value_per_node = dat[2][range] ./ dat[1][range]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1][range] * 8, efficiency, label = "", marker = mark)
        end
    end

    plt = plot(plt1, plt3, plt2, layout=(3,1))
    display(plt)
end
# Out:
# Zcs/sec
#   singleBH-Z4cowGPU-5Levels: [ 1.79e+09, 2.73e+09, 5.78e+09, 9.52e+09, 1.89e+10, 3.48e+10, 7.05e+10, 1.25e+11]

# %% [markdown]
# ## Level6

# %%
let patt_dirss = [
        ([
            (r"singleBH_Z4cowGPU_L6_N\d+_r0000", "singleBH-Z4cowGPU-6Levels"),
        ], "../data/singleBH-Scaling/Levels6/Block8/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [8, 16, 32, 64, 128, 256, 512, 1024]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [4e9, 8e9, 1.6e10]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])
    
    plt3 = plot(ylabel=L"\mathrm{Zcs/sec/GPU}", xscale=:log10)
    xticks!(plt3, xs, [string(n) for n in xs])
    ys = [5e7, 5.5e7]
    yticks!(plt3, ys, [string(n) for n in ys])
    
    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1] * 8, dat[2], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1] * 8, dat[2][1] .* dat[1] / 8, label="", linestyle=:dash, color=:lightgray)
            
            plot!(plt3, dat[1] * 8, dat[2] ./ (dat[1] * 8), label = "",  marker = mark)
            
            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Efficiency
            value_per_node = dat[2] ./ dat[1]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1] * 8, efficiency, label = "", marker = mark)
        end
    end

    plt = plot(plt1, plt3, plt2, layout=(3,1))
    display(plt)
end
# Out:
# Zcs/sec
#   singleBH-Z4cowGPU-6Levels: [ 3.77e+09, 6.64e+09, 1.30e+10, 2.45e+10]

# %% [markdown]
# ## Level7

# %% [markdown]
# ### Block8

# %%
let patt_dirss = [
        ([
            (r"singleBH_Z4cowGPU_L7_N\d+_r0000", "singleBH-Z4cowGPU-7Levels"),
        ], "../data/singleBH-Scaling/Levels7/Block8/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [1e9, 4e9, 1.6e10, 6.4e10, 2.56e11]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])
    
    plt3 = plot(ylabel=L"\mathrm{Zcs/sec/GPU}", xscale=:log10)
    xticks!(plt3, xs, [string(n) for n in xs])
    ys = [6e7, 7e7, 8e7]
    yticks!(plt3, ys, [string(n) for n in ys])
    
    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1] * 8, dat[2], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1] * 8, dat[2][1] .* dat[1], label="", linestyle=:dash, color=:lightgray)
            
            plot!(plt3, dat[1] * 8, dat[2] ./ (dat[1] * 8), label = "",  marker = mark)
            
            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Efficiency
            value_per_node = dat[2] ./ dat[1]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1] * 8, efficiency, label = "", marker = mark)
        end
    end

    plt = plot(plt1, plt3, plt2, layout=(3,1))
    display(plt)
end
# Out:
# Zcs/sec
#   singleBH-Z4cowGPU-7Levels: [ 6.77e+08, 1.32e+09, 2.42e+09, 4.57e+09, 8.34e+09, 1.64e+10, 3.22e+10, 6.23e+10, 1.21e+11, 2.25e+11, 4.45e+11]

# %% [markdown]
# ### Block32

# %%
let patt_dirss = [
        ([
            (r"singleBH_Z4cowGPU_L7_N\d+_r0000", "singleBH-Z4cowGPU-7Levels"),
        ], "../data/singleBH-Scaling/Levels7/Block32/", :cross),
    ]

    # Plot Zcs/sec
    plt1 = plot(ylabel=L"\mathrm{Zcs}/\mathrm{sec}", xscale=:log10, yscale=:log10)
    xs = [8, 16, 32, 64, 128, 256, 512, 1024]
    xticks!(plt1, xs, [string(n) for n in xs])
    ys = [4e9, 8e9, 1.6e10]
    yticks!(plt1, ys, [string(n) for n in ys])

    # Plot Efficiency
    plt2 = plot(ylabel=L"\mathrm{Efficiency}", xscale=:log10)
    xticks!(plt2, xs, [string(n) for n in xs])
    
    plt3 = plot(ylabel=L"\mathrm{Zcs/sec/GPU}", xscale=:log10)
    xticks!(plt3, xs, [string(n) for n in xs])
    ys = [6.5e7, 7e7, 7.5e7, 8e7]
    yticks!(plt3, ys, [string(n) for n in ys])
    
    println("Zcs/sec")
    for (patterns, parent_dir, mark) in patt_dirss
        # Load averages for the given patterns and directory
        dats, labs = MiscStdout.load_avgs(patterns, parent_dir; option = "ZcsPerSecond", range=:)
        # Iterate through the loaded datasets
        for (i, dat) in enumerate(dats)
            # Plot Zcs/sec
            plot!(plt1, dat[1] * 8, dat[2], label = L"\mathrm{%$(labs[i])}", marker = mark)
            plot!(plt1, dat[1] * 8, dat[2][1] .* dat[1], label="", linestyle=:dash, color=:lightgray)
            
            plot!(plt3, dat[1] * 8, dat[2] ./ (dat[1] * 8), label = "",  marker = mark)
            
            @printf("  %8s: [", labs[i])
            println(join([@sprintf(" %8.2e", d) for d in dat[2]], ","), "]")

            # Plot Efficiency
            value_per_node = dat[2] ./ dat[1]
            efficiency = value_per_node ./ first(value_per_node)
            plot!(plt2, dat[1] * 8, efficiency, label = "", marker = mark)
        end
    end

    plt = plot(plt1, plt3, plt2, layout=(3,1))
    display(plt)
end
# Out:
# Zcs/sec
#   singleBH-Z4cowGPU-7Levels: [ 6.76e+08, 1.30e+09, 2.42e+09, 4.57e+09, 8.25e+09, 1.64e+10, 3.16e+10]

# %% [markdown]
# ## Speed

# %%
let patt_dirss = [
        ([
            (r"singleBH_Z4cowGPU_L7_N\d+_r0000", ""),
        ], "../data/singleBH-Scaling/Levels7/Block8/", :cross),
    ]
    
    #
    plts = []
    for (patterns, parent_dir, mark) in patt_dirss
        (vals, titles) = MiscStdout.load_values(patterns, parent_dir; option="TotalComputeTime")
        for (j, val) in enumerate(vals)
            (dats, labs) = val
            plt = plot(title=titles[j])
            for (i, dat) in enumerate(dats)
                plot!(plt, dat[1], dat[4], label=labs[i])
            end
            push!(plts, plt)
        end
    end
    
    plt = plot(plts..., layout=(1,1))
    display(plt)
end
